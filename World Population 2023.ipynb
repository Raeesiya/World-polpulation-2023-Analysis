# %% [markdown]
# # World population 2023 Analysis

# %% [markdown]
# •	Two major sources that assess and publish global population are : the United Nations and the U.S. Census Bureau
# •	The United Nations Population Division of the Department of Economic and Social Affairs every two years calculates, updates, and publishes estimates of total population in its World Population Prospects series
# •	These population estimates and projections provide the standard and consistent set of population figures that are used throughout the United Nations system
# ###### Present Dataset contains list of 205 countries including dependent territories
# •	Dependent territory also known as dependent area, or dependency or an external territory is a territory that does not possess full political independence or sovereignty as a sovereign state, yet remains politically outside the controlling state's integral area
# •	Rank allocated to each country and dependencies are according to their population size by United Nations
# •	Dataset contains nine columns which hold information for each country and dependent territory

# %% [markdown]
# #### Columns:
# •	country name : Names of 205 countries including dependent terroitories in the world
# •	current population : current population i.e population as of January 2023
# •	population 2022: population for the previous year i.e. 2022
# •	area: Area in kilometer square (km^2)
# •	land area: Land area in km^2
# •	density: Population density i.e. people per sq. km of land area in /km^2
# •	growth rate: Annual growth rate where +ve and -ve signs show an increase and decrease in growth rates respectively
# •	world percentage: share of each country in total world's population in terms of percentage
# •	rank: rank on the basis of population size, most populated country is assigned highest rank

# %%
#Import Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
df=pd.read_excel('C:/Users/user/OneDrive/Desktop/raeesiya/worldpopulation2023.xlsx')
df
# Out:
#       country name  current population  population 2022   area  land area  \
# 0            India          1423118510       1417173173    3.3        3.0
# 1            China          1425820141       1425887337    9.7        9.4
# 2    United States           339231549        338289857    9.4        9.1
# 3        Indonesia           276576867        275501339    1.9        1.9
# 4         Pakistan           238517163        235824862  881.9      770.9
# ..             ...                 ...              ...    ...        ...
# 200     San Marino               33642            33660   61.0       60.0
# 201          Palau               18058            18055  459.0      460.0
# 202          Nauru               12780            12668   21.0       20.0
# 203         Tuvalu               11396            11312   26.0       30.0
# 204   Vatican City                 518              510    1.0        1.0
#
#      density  growth rate  world percentage  rank
# 0      481.0         0.81             17.85     1
# 1      151.0        -0.02             17.81     2
# 2       37.0         0.50              4.25     3
# 3      148.0         0.74              3.47     4
# 4      312.0         1.98              3.00     5
# ..       ...          ...               ...   ...
# 200    561.0        -0.05              0.00   218
# 201     39.0         0.02              0.00   222
# 202    639.0         0.88              0.00   225
# 203    380.0         0.74              0.00   227
# 204   1177.0         1.57               NaN   234
#
# [205 rows x 9 columns]

# %%
#access the structue of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country name        205 non-null    object
#  1   current population  205 non-null    int64
#  2   population 2022     205 non-null    int64
#  3   area                205 non-null    float64
#  4   land area           205 non-null    float64
#  5   density             205 non-null    float64
#  6   growth rate         205 non-null    float64
#  7   world percentage    204 non-null    float64
#  8   rank                205 non-null    int64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 14.5+ KB

# %%
#To display first 5 rows
df.head()
# Out:
#     country name  current population  population 2022   area  land area  \
# 0          India          1423118510       1417173173    3.3        3.0
# 1          China          1425820141       1425887337    9.7        9.4
# 2  United States           339231549        338289857    9.4        9.1
# 3      Indonesia           276576867        275501339    1.9        1.9
# 4       Pakistan           238517163        235824862  881.9      770.9
#
#    density  growth rate  world percentage  rank
# 0    481.0         0.81             17.85     1
# 1    151.0        -0.02             17.81     2
# 2     37.0         0.50              4.25     3
# 3    148.0         0.74              3.47     4
# 4    312.0         1.98              3.00     5

# %%
#To display last 5 rows
df.tail()
# Out:
#      country name  current population  population 2022   area  land area  \
# 200    San Marino               33642            33660   61.0       60.0
# 201         Palau               18058            18055  459.0      460.0
# 202         Nauru               12780            12668   21.0       20.0
# 203        Tuvalu               11396            11312   26.0       30.0
# 204  Vatican City                 518              510    1.0        1.0
#
#      density  growth rate  world percentage  rank
# 200    561.0        -0.05               0.0   218
# 201     39.0         0.02               0.0   222
# 202    639.0         0.88               0.0   225
# 203    380.0         0.74               0.0   227
# 204   1177.0         1.57               NaN   234

# %%
#To display statistics for numerical columns in a data
df.describe()
# Out:
#        current population  population 2022        area   land area  \
# count        2.050000e+02     2.050000e+02  205.000000  205.000000
# mean         3.907452e+07     3.888173e+07  209.801463  207.443902
# std          1.458696e+08     1.455222e+08  251.650441  247.310747
# min          5.180000e+02     5.100000e+02    1.000000    1.000000
# 25%          1.480242e+06     1.472233e+06   13.900000   14.900000
# 50%          7.590327e+06     7.529475e+06   89.300000   91.300000
# 75%          2.857019e+07     2.816054e+07  338.400000  340.000000
# max          1.425820e+09     1.425887e+09  964.000000  960.000000
#
#             density  growth rate  world percentage        rank
# count    205.000000   205.000000        204.000000  205.000000
# mean     344.059220     1.064878          0.492549  104.351220
# std     1482.715257     1.277604          1.830375   61.585136
# min        0.140000    -7.450000          0.000000    1.000000
# 25%       35.000000     0.310000          0.020000   52.000000
# 50%       95.000000     0.890000          0.105000  103.000000
# 75%      235.000000     1.920000          0.360000  154.000000
# max    18149.000000     4.980000         17.850000  234.000000

# %%
#check for missing (null) values in a Data
df.isnull().sum()
# Out:
# country name          0
# current population    0
# population 2022       0
# area                  0
# land area             0
# density               0
# growth rate           0
# world percentage      1
# rank                  0
# dtype: int64

# %%
# Correct way to fill null values in the "World Percentage" column with its mean
df["world percentage"] = df["world percentage"].fillna(df["world percentage"].mean())
df
# Out:
#       country name  current population  population 2022   area  land area  \
# 0            India          1423118510       1417173173    3.3        3.0
# 1            China          1425820141       1425887337    9.7        9.4
# 2    United States           339231549        338289857    9.4        9.1
# 3        Indonesia           276576867        275501339    1.9        1.9
# 4         Pakistan           238517163        235824862  881.9      770.9
# ..             ...                 ...              ...    ...        ...
# 200     San Marino               33642            33660   61.0       60.0
# 201          Palau               18058            18055  459.0      460.0
# 202          Nauru               12780            12668   21.0       20.0
# 203         Tuvalu               11396            11312   26.0       30.0
# 204   Vatican City                 518              510    1.0        1.0
#
#      density  growth rate  world percentage  rank
# 0      481.0         0.81         17.850000     1
# 1      151.0        -0.02         17.810000     2
# 2       37.0         0.50          4.250000     3
# 3      148.0         0.74          3.470000     4
# 4      312.0         1.98          3.000000     5
# ..       ...          ...               ...   ...
# 200    561.0        -0.05          0.000000   218
# 201     39.0         0.02          0.000000   222
# 202    639.0         0.88          0.000000   225
# 203    380.0         0.74          0.000000   227
# 204   1177.0         1.57          0.492549   234
#
# [205 rows x 9 columns]

# %%
#check for missing (null) values in a Data
df.isnull().sum()
# Out:
# country name          0
# current population    0
# population 2022       0
# area                  0
# land area             0
# density               0
# growth rate           0
# world percentage      0
# rank                  0
# dtype: int64

# %% [markdown]
# ### Bar graph

# %%
df.columns =df.columns.str.strip()
df['current population'] = pd.to_numeric(df['current population'], errors='coerce')

# Filter top 10 countries by 'World Percentage'
top_10 = df.nlargest(10, 'current population')

# Plot
plt.figure(figsize=(10, 6))
plt.bar(top_10['country name'], top_10['current population'], color='skyblue')
plt.title("Top 10 Countries by current population", fontsize=16)
plt.xlabel("Country", fontsize=12)
plt.ylabel("current population ", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### pie chart

# %%
plt.figure(figsize=(8, 8))
plt.pie(df['world percentage'], labels=df['country name'], autopct='%1.1f%%', startangle=140)
plt.title("World Percentage by Country", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Line chart

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['growth rate'],df['current population'], marker='o', linestyle='-', color='b')
plt.title("Population vs growth rate", fontsize=16)
plt.xlabel("growth rate", fontsize=12)
plt.ylabel("Population", fontsize=12)
plt.grid(alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['country name'], df['current population'], alpha=0.7, color='green')
plt.title("Population vs country name", fontsize=16)
plt.xlabel("country name", fontsize=12)
plt.ylabel("current population", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### bar graph

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['current population'], bins=10, color='blue', alpha=0.7)
plt.title("Distribution of Population 2023", fontsize=16)
plt.xlabel("current population", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.tight_layout()
plt.show()
